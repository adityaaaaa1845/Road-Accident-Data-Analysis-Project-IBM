# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/Data Analytics  IBM/Road_Accident_Data_India_2024.csv")
data
# Out:
#     Accident_ID        Date       State/UT       City Weather_Condition  \
# 0       ACC1000  2024-12-06  Uttar Pradesh  Bengaluru             Clear
# 1       ACC1001  2024-11-08  Uttar Pradesh     Jaipur             Clear
# 2       ACC1002  2024-06-11          Bihar     Jaipur             Clear
# 3       ACC1003  2024-11-29    Maharashtra  Ahmedabad             Clear
# 4       ACC1004  2024-01-27      Karnataka      Patna             Clear
# ..          ...         ...            ...        ...               ...
# 995     ACC1995  2024-08-21      Karnataka      Delhi             Foggy
# 996     ACC1996  2024-05-10     Tamil Nadu  Bengaluru             Windy
# 997     ACC1997  2024-01-19    Maharashtra  Bengaluru             Rainy
# 998     ACC1998  2024-12-31        Gujarat  Bengaluru             Windy
# 999     ACC1999  2024-01-22    Maharashtra    Kolkata            Cloudy
#
#       Road_Type Vehicle_Type Severity  No_of_Vehicles_Involved  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Accident_ID              1000 non-null   object
#  1   Date                     1000 non-null   object
#  2   State/UT                 1000 non-null   object
#  3   City                     1000 non-null   object
#  4   Weather_Condition        1000 non-null   object
#  5   Road_Type                1000 non-null   object
#  6   Vehicle_Type             1000 non-null   object
#  7   Severity                 1000 non-null   object
#  8   No_of_Vehicles_Involved  1000 non-null   int64
#  9   No_of_Persons_Injured    1000 non-null   int64
#  10  No_of_Persons_Killed     1000 non-null   int64
#  11  Cause                    1000 non-null   object
#  12  Time_of_Day              1000 non-null   object
# dtypes: int64(3), object(10)
# memory usage: 101.7+ KB

# %%
mean = data['No_of_Persons_Injured'].mean()
print(mean)
# Out:
# 2.539

# %%
median = data['No_of_Vehicles_Involved'].median()
print(median)
# Out:
# 2.0

# %%
mode = data['No_of_Vehicles_Involved'].mode()
print(mode)
# Out:
# 0    1
# Name: No_of_Vehicles_Involved, dtype: int64

# %%
data.head()
# Out:
#   Accident_ID        Date       State/UT       City Weather_Condition  \
# 0     ACC1000  2024-12-06  Uttar Pradesh  Bengaluru             Clear
# 1     ACC1001  2024-11-08  Uttar Pradesh     Jaipur             Clear
# 2     ACC1002  2024-06-11          Bihar     Jaipur             Clear
# 3     ACC1003  2024-11-29    Maharashtra  Ahmedabad             Clear
# 4     ACC1004  2024-01-27      Karnataka      Patna             Clear
#
#     Road_Type Vehicle_Type Severity  No_of_Vehicles_Involved  \
# 0  Rural Road         Auto    Fatal                        2
# 1   City Road          Car    Major                        2
# 2     Highway         Auto    Minor                        1
# 3  Rural Road          Car    Major                        3
# 4  Rural Road        Truck    Minor                        4
#
#    No_of_Persons_Injured  No_of_Persons_Killed               Cause Time_of_Day
# 0                      0                     1       Over-speeding     Morning
# ...

# %%
data.tail()
# Out:
#     Accident_ID        Date     State/UT       City Weather_Condition  \
# 995     ACC1995  2024-08-21    Karnataka      Delhi             Foggy
# 996     ACC1996  2024-05-10   Tamil Nadu  Bengaluru             Windy
# 997     ACC1997  2024-01-19  Maharashtra  Bengaluru             Rainy
# 998     ACC1998  2024-12-31      Gujarat  Bengaluru             Windy
# 999     ACC1999  2024-01-22  Maharashtra    Kolkata            Cloudy
#
#       Road_Type Vehicle_Type Severity  No_of_Vehicles_Involved  \
# 995   City Road         Auto    Major                        4
# 996  Rural Road         Bike    Fatal                        1
# 997     Highway          Bus    Major                        3
# 998     Highway          Car    Fatal                        1
# 999  Rural Road          Bus    Major                        2
#
#      No_of_Persons_Injured  No_of_Persons_Killed               Cause  \
# 995                      2                     0  Distracted Driving
# ...

# %%
data.shape
# Out:
# (1000, 13)

# %%
data.describe()
# Out:
#        No_of_Vehicles_Involved  No_of_Persons_Injured  No_of_Persons_Killed
# count              1000.000000             1000.00000           1000.000000
# mean                  2.479000                2.53900              1.449000
# std                   1.142306                1.67848              1.112941
# min                   1.000000                0.00000              0.000000
# 25%                   1.000000                1.00000              0.000000
# 50%                   2.000000                3.00000              1.000000
# 75%                   4.000000                4.00000              2.000000
# max                   4.000000                5.00000              3.000000

# %%
data.isnull().sum()
# Out:
# Accident_ID                0
# Date                       0
# State/UT                   0
# City                       0
# Weather_Condition          0
# Road_Type                  0
# Vehicle_Type               0
# Severity                   0
# No_of_Vehicles_Involved    0
# No_of_Persons_Injured      0
# No_of_Persons_Killed       0
# Cause                      0
# Time_of_Day                0
# dtype: int64

# %%
dropped_data = data.dropna()
dropped_data
# Out:
#     Accident_ID        Date       State/UT       City Weather_Condition  \
# 0       ACC1000  2024-12-06  Uttar Pradesh  Bengaluru             Clear
# 1       ACC1001  2024-11-08  Uttar Pradesh     Jaipur             Clear
# 2       ACC1002  2024-06-11          Bihar     Jaipur             Clear
# 3       ACC1003  2024-11-29    Maharashtra  Ahmedabad             Clear
# 4       ACC1004  2024-01-27      Karnataka      Patna             Clear
# ..          ...         ...            ...        ...               ...
# 995     ACC1995  2024-08-21      Karnataka      Delhi             Foggy
# 996     ACC1996  2024-05-10     Tamil Nadu  Bengaluru             Windy
# 997     ACC1997  2024-01-19    Maharashtra  Bengaluru             Rainy
# 998     ACC1998  2024-12-31        Gujarat  Bengaluru             Windy
# 999     ACC1999  2024-01-22    Maharashtra    Kolkata            Cloudy
#
#       Road_Type Vehicle_Type Severity  No_of_Vehicles_Involved  \
# ...

# %%
data.columns
# Out:
# Index(['Accident_ID', 'Date', 'State/UT', 'City', 'Weather_Condition',
#        'Road_Type', 'Vehicle_Type', 'Severity', 'No_of_Vehicles_Involved',
#        'No_of_Persons_Injured', 'No_of_Persons_Killed', 'Cause',
#        'Time_of_Day'],
#       dtype='object')

# %%
df = data['No_of_Persons_Injured'].fillna(mean)
df
# Out:
# 0      0
# 1      4
# 2      2
# 3      5
# 4      2
#       ..
# 995    2
# 996    0
# 997    5
# 998    1
# 999    4
# Name: No_of_Persons_Injured, Length: 1000, dtype: int64

# %%
da = data['No_of_Vehicles_Involved'].fillna(median)
da
# Out:
# 0      2
# 1      2
# 2      1
# 3      3
# 4      4
#       ..
# 995    4
# 996    1
# 997    3
# 998    1
# 999    2
# Name: No_of_Vehicles_Involved, Length: 1000, dtype: int64

# %%
data.fillna(method='ffill')
# Out:
# /tmp/ipython-input-1844443866.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill')
#     Accident_ID        Date       State/UT       City Weather_Condition  \
# 0       ACC1000  2024-12-06  Uttar Pradesh  Bengaluru             Clear
# 1       ACC1001  2024-11-08  Uttar Pradesh     Jaipur             Clear
# 2       ACC1002  2024-06-11          Bihar     Jaipur             Clear
# 3       ACC1003  2024-11-29    Maharashtra  Ahmedabad             Clear
# 4       ACC1004  2024-01-27      Karnataka      Patna             Clear
# ..          ...         ...            ...        ...               ...
# 995     ACC1995  2024-08-21      Karnataka      Delhi             Foggy
# 996     ACC1996  2024-05-10     Tamil Nadu  Bengaluru             Windy
# 997     ACC1997  2024-01-19    Maharashtra  Bengaluru             Rainy
# ...

# %%
data.fillna(method='bfill')
# Out:
# /tmp/ipython-input-1397359497.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill')
#     Accident_ID        Date       State/UT       City Weather_Condition  \
# 0       ACC1000  2024-12-06  Uttar Pradesh  Bengaluru             Clear
# 1       ACC1001  2024-11-08  Uttar Pradesh     Jaipur             Clear
# 2       ACC1002  2024-06-11          Bihar     Jaipur             Clear
# 3       ACC1003  2024-11-29    Maharashtra  Ahmedabad             Clear
# 4       ACC1004  2024-01-27      Karnataka      Patna             Clear
# ..          ...         ...            ...        ...               ...
# 995     ACC1995  2024-08-21      Karnataka      Delhi             Foggy
# 996     ACC1996  2024-05-10     Tamil Nadu  Bengaluru             Windy
# 997     ACC1997  2024-01-19    Maharashtra  Bengaluru             Rainy
# ...

# %%
data.fillna('Apple')
# Out:
#     Accident_ID        Date       State/UT       City Weather_Condition  \
# 0       ACC1000  2024-12-06  Uttar Pradesh  Bengaluru             Clear
# 1       ACC1001  2024-11-08  Uttar Pradesh     Jaipur             Clear
# 2       ACC1002  2024-06-11          Bihar     Jaipur             Clear
# 3       ACC1003  2024-11-29    Maharashtra  Ahmedabad             Clear
# 4       ACC1004  2024-01-27      Karnataka      Patna             Clear
# ..          ...         ...            ...        ...               ...
# 995     ACC1995  2024-08-21      Karnataka      Delhi             Foggy
# 996     ACC1996  2024-05-10     Tamil Nadu  Bengaluru             Windy
# 997     ACC1997  2024-01-19    Maharashtra  Bengaluru             Rainy
# 998     ACC1998  2024-12-31        Gujarat  Bengaluru             Windy
# 999     ACC1999  2024-01-22    Maharashtra    Kolkata            Cloudy
#
#       Road_Type Vehicle_Type Severity  No_of_Vehicles_Involved  \
# ...

# %%
da.astype(int)
# Out:
# 0      2
# 1      2
# 2      1
# 3      3
# 4      4
#       ..
# 995    4
# 996    1
# 997    3
# 998    1
# 999    2
# Name: No_of_Vehicles_Involved, Length: 1000, dtype: int64

# %%
sort_values = data.sort_values(by='City',ascending=False)
sort_values
# Out:
#     Accident_ID        Date       State/UT       City Weather_Condition  \
# 164     ACC1164  2024-07-28    Maharashtra      Patna             Clear
# 192     ACC1192  2024-03-19          Delhi      Patna             Clear
# 839     ACC1839  2024-05-19          Bihar      Patna             Clear
# 205     ACC1205  2024-07-24  Uttar Pradesh      Patna             Foggy
# 587     ACC1587  2024-02-17      Karnataka      Patna             Windy
# ..          ...         ...            ...        ...               ...
# 125     ACC1125  2024-03-04        Gujarat  Ahmedabad             Rainy
# 316     ACC1316  2024-09-26    Maharashtra  Ahmedabad             Clear
# 318     ACC1318  2024-07-19          Delhi  Ahmedabad             Clear
# 721     ACC1721  2024-03-31      Karnataka  Ahmedabad            Cloudy
# 766     ACC1766  2024-03-23    Maharashtra  Ahmedabad             Rainy
#
#       Road_Type Vehicle_Type Severity  No_of_Vehicles_Involved  \
# ...

# %%
sort_values = data.sort_values(by='City',ascending=True)
sort_values
# Out:
#     Accident_ID        Date        State/UT       City Weather_Condition  \
# 624     ACC1624  2024-10-05           Delhi  Ahmedabad             Foggy
# 715     ACC1715  2024-05-20     West Bengal  Ahmedabad            Cloudy
# 468     ACC1468  2024-12-31         Gujarat  Ahmedabad             Rainy
# 721     ACC1721  2024-03-31       Karnataka  Ahmedabad            Cloudy
# 453     ACC1453  2024-02-13      Tamil Nadu  Ahmedabad             Clear
# ..          ...         ...             ...        ...               ...
# 146     ACC1146  2024-03-03   Uttar Pradesh      Patna             Foggy
# 213     ACC1213  2024-01-01  Madhya Pradesh      Patna             Foggy
# 893     ACC1893  2024-03-24       Karnataka      Patna             Foggy
# 611     ACC1611  2024-05-10           Bihar      Patna             Clear
# 107     ACC1107  2024-10-04   Uttar Pradesh      Patna             Windy
#
#       Road_Type Vehicle_Type Severity  No_of_Vehicles_Involved  \
# ...

# %%
filtered_data = data[data['No_of_Persons_Killed'] > 1]
filtered_data
# Out:
#     Accident_ID        Date        State/UT       City Weather_Condition  \
# 2       ACC1002  2024-06-11           Bihar     Jaipur             Clear
# 4       ACC1004  2024-01-27       Karnataka      Patna             Clear
# 5       ACC1005  2024-09-11       Karnataka    Lucknow             Clear
# 7       ACC1007  2024-03-06  Madhya Pradesh    Chennai             Clear
# 10      ACC1010  2024-01-14       Karnataka     Mumbai             Rainy
# ..          ...         ...             ...        ...               ...
# 990     ACC1990  2024-04-26     Maharashtra  Bengaluru             Foggy
# 992     ACC1992  2024-11-22     West Bengal     Bhopal             Windy
# 993     ACC1993  2024-08-14   Uttar Pradesh     Bhopal             Foggy
# 997     ACC1997  2024-01-19     Maharashtra  Bengaluru             Rainy
# 998     ACC1998  2024-12-31         Gujarat  Bengaluru             Windy
#
#       Road_Type Vehicle_Type Severity  No_of_Vehicles_Involved  \
# ...

# %%
filtered_data = data[(data['No_of_Persons_Killed'] > 1) & (data['No_of_Persons_Injured'] > 1)]
filtered_data
# Out:
#     Accident_ID        Date       State/UT       City Weather_Condition  \
# 2       ACC1002  2024-06-11          Bihar     Jaipur             Clear
# 4       ACC1004  2024-01-27      Karnataka      Patna             Clear
# 15      ACC1015  2024-03-04        Gujarat  Ahmedabad             Windy
# 17      ACC1017  2024-02-27    Maharashtra  Ahmedabad             Clear
# 18      ACC1018  2024-06-09      Rajasthan     Bhopal             Clear
# ..          ...         ...            ...        ...               ...
# 981     ACC1981  2024-04-14     Tamil Nadu    Chennai            Cloudy
# 983     ACC1983  2024-03-04  Uttar Pradesh     Mumbai             Rainy
# 990     ACC1990  2024-04-26    Maharashtra  Bengaluru             Foggy
# 992     ACC1992  2024-11-22    West Bengal     Bhopal             Windy
# 997     ACC1997  2024-01-19    Maharashtra  Bengaluru             Rainy
#
#       Road_Type Vehicle_Type Severity  No_of_Vehicles_Involved  \
# ...

# %%
data.groupby('City')['No_of_Persons_Killed'].median()
# Out:
# City
# Ahmedabad    1.0
# Bengaluru    2.0
# Bhopal       1.0
# Chennai      1.0
# Delhi        1.0
# Jaipur       1.0
# Kolkata      2.0
# Lucknow      2.0
# Mumbai       1.0
# Patna        1.0
# Name: No_of_Persons_Killed, dtype: float64

# %%
data.groupby('City')['No_of_Persons_Killed'].mean()
# Out:
# City
# Ahmedabad    1.412698
# Bengaluru    1.674699
# Bhopal       1.260417
# Chennai      1.432692
# Delhi        1.378641
# Jaipur       1.430108
# Kolkata      1.561905
# Lucknow      1.676190
# Mumbai       1.319149
# Patna        1.351648
# Name: No_of_Persons_Killed, dtype: float64

# %%
pivot_table = pd.pivot_table(data, values='No_of_Persons_Killed', index='City', aggfunc='sum')
pivot_table
# Out:
#            No_of_Persons_Killed
# City
# Ahmedabad                   178
# Bengaluru                   139
# Bhopal                      121
# Chennai                     149
# Delhi                       142
# Jaipur                      133
# Kolkata                     164
# Lucknow                     176
# Mumbai                      124
# Patna                       123

# %%
pivot_table = pd.pivot_table(data, values='No_of_Persons_Killed', index='City', aggfunc='mean')
pivot_table
# Out:
#            No_of_Persons_Killed
# City
# Ahmedabad              1.412698
# Bengaluru              1.674699
# Bhopal                 1.260417
# Chennai                1.432692
# Delhi                  1.378641
# Jaipur                 1.430108
# Kolkata                1.561905
# Lucknow                1.676190
# Mumbai                 1.319149
# Patna                  1.351648

# %%
pivot_table = pd.pivot_table(data, values='No_of_Persons_Killed', index='City', aggfunc='median')
pivot_table
# Out:
#            No_of_Persons_Killed
# City
# Ahmedabad                   1.0
# Bengaluru                   2.0
# Bhopal                      1.0
# Chennai                     1.0
# Delhi                       1.0
# Jaipur                      1.0
# Kolkata                     2.0
# Lucknow                     2.0
# Mumbai                      1.0
# Patna                       1.0

# %%
import matplotlib.pyplot as plt

# %%
data.plot(x="Vehicle_Type",y="No_of_Persons_Injured")
# Out:
# <Axes: xlabel='Vehicle_Type'>

# %%
data.plot(x="Vehicle_Type",y="No_of_Persons_Injured",color= "Orange" , figsize=(10,5),marker = "*")
plt.xlabel("Vehicle_Type")
plt.ylabel("No_of_Persons_Injured")
plt.show()

# %%
data.plot(x="Road_Type",y="No_of_Persons_Injured",color= "Purple" , figsize=(10,5),kind = "bar")
plt.xlabel("Road_Type")
plt.ylabel("No_of_Persons_Injured")
plt.title("Bar_graph")
plt.show()

# %%
data.plot(x="Road_Type",y="No_of_Persons_Injured",color= "Red" , figsize=(10,5), marker = "o",kind = "line")
plt.xlabel("Road_Type	")
plt.ylabel("No_of_Persons_Injured")
plt.title("Bar_graph")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
data.plot(x="Weather_Condition",y="No_of_Persons_Killed",kind = "bar")
# Out:
# <Axes: xlabel='Weather_Condition'>

# %%
same = data.groupby('Severity')['No_of_Persons_Killed'].mean()
same.plot(kind='bar')
# Out:
# <Axes: xlabel='Severity'>

# %%
same = data.groupby('City')['No_of_Persons_Killed'].mean()
same.plot(kind='bar',edgecolor="Yellow", width = 0.8)
# Out:
# <Axes: xlabel='City'>

# %%
same = data.groupby('City')['No_of_Persons_Killed'].mean()
colors = ("red" , "grey" , "blue" , "green" , "purple","orange" , "black", "cyan" , "white" , "magenta")
same.plot(kind = "bar",edgecolor="Yellow", width = 0.8,color=colors)
# Out:
# <Axes: xlabel='City'>

# %%
data.plot(x= "Time_of_Day" , y= "No_of_Persons_Killed" , kind = "scatter")
# Out:
# <Axes: xlabel='Time_of_Day', ylabel='No_of_Persons_Killed'>
